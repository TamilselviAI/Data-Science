# %%
import pandas as pd
dataset = pd.read_csv("HRDataset_v14.csv")

# %%
dataset
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
dataset.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
## if status is not placed, those are 67 count
# Replace the missing value with central tendency - Mean, Median. Mode
# or delete the entire row
# Respective to the problem, have to replace the missing values
# consider this as semi supervised, create a model, so that we can predict missing values

# %%
dataset.isna().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
dataset["DateofTermination"].fillna(0,inplace=True)
dataset["ManagerID"].fillna(0,inplace=True)
# Out:
# C:\Users\Ganesh\AppData\Local\Temp\ipykernel_8824\3916508957.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["DateofTermination"].fillna(0,inplace=True)
# C:\Users\Ganesh\AppData\Local\Temp\ipykernel_8824\3916508957.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
dataset.isnull().sum()
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# ...

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanQual(dataset)

# %%
dataset[quan]
# Out:
#      EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  DeptID  \
# 0    10026          0                0         1            1       5
# 1    10084          1                1         1            5       3
# 2    10196          1                1         0            5       5
# 3    10088          1                1         0            1       5
# 4    10069          0                2         0            5       5
# ..     ...        ...              ...       ...          ...     ...
# 306  10135          0                0         1            1       5
# 307  10301          0                0         0            5       5
# 308  10010          0                0         0            1       3
# 309  10043          0                0         0            1       3
# 310  10271          0                4         0            1       5
#
#      PerfScoreID  FromDiversityJobFairID  Salary  Termd  PositionID   Zip  \
# ...

# %%
dataset[qual]
# Out:
#                 Employee_Name                  Position State       DOB Sex  \
# 0         Adinolfi, Wilson  K   Production Technician I    MA  07/10/83  M
# 1    Ait Sidi, Karthikeyan                      Sr. DBA    MA  05/05/75  M
# 2           Akinkuolie, Sarah  Production Technician II    MA  09/19/88   F
# 3                Alagbe,Trina   Production Technician I    MA  09/27/88   F
# 4            Anderson, Carol    Production Technician I    MA  09/08/89   F
# ..                        ...                       ...   ...       ...  ..
# 306            Woodson, Jason  Production Technician II    MA  05/11/85  M
# 307        Ybarra, Catherine    Production Technician I    MA  05/04/82   F
# 308          Zamora, Jennifer                       CIO    MA  08/30/79   F
# 309               Zhou, Julia              Data Analyst    MA  02/24/79   F
# 310             Zima, Colleen   Production Technician I    MA  08/17/78   F
#
# ...

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
df=imp.transform(dataset[quan])
df = pd.DataFrame(df,columns = quan)

# %%
df
# Out:
#        EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  DeptID  \
# 0    10026.0        0.0              0.0       1.0          1.0     5.0
# 1    10084.0        1.0              1.0       1.0          5.0     3.0
# 2    10196.0        1.0              1.0       0.0          5.0     5.0
# 3    10088.0        1.0              1.0       0.0          1.0     5.0
# 4    10069.0        0.0              2.0       0.0          5.0     5.0
# ..       ...        ...              ...       ...          ...     ...
# 306  10135.0        0.0              0.0       1.0          1.0     5.0
# 307  10301.0        0.0              0.0       0.0          5.0     5.0
# 308  10010.0        0.0              0.0       0.0          1.0     3.0
# 309  10043.0        0.0              0.0       0.0          1.0     3.0
# 310  10271.0        0.0              4.0       0.0          1.0     5.0
#
#      PerfScoreID  FromDiversityJobFairID    Salary  Termd  PositionID     Zip  \
# ...

# %%
cate=dataset[qaul]

# %%
cate
# Out:
#                 Employee_Name                  Position State       DOB Sex  \
# 0         Adinolfi, Wilson  K   Production Technician I    MA  07/10/83  M
# 1    Ait Sidi, Karthikeyan                      Sr. DBA    MA  05/05/75  M
# 2           Akinkuolie, Sarah  Production Technician II    MA  09/19/88   F
# 3                Alagbe,Trina   Production Technician I    MA  09/27/88   F
# 4            Anderson, Carol    Production Technician I    MA  09/08/89   F
# ..                        ...                       ...   ...       ...  ..
# 306            Woodson, Jason  Production Technician II    MA  05/11/85  M
# 307        Ybarra, Catherine    Production Technician I    MA  05/04/82   F
# 308          Zamora, Jennifer                       CIO    MA  08/30/79   F
# 309               Zhou, Julia              Data Analyst    MA  02/24/79   F
# 310             Zima, Colleen   Production Technician I    MA  08/17/78   F
#
# ...

# %%
two=[df,cate]

# %%
preprocessed=pd.concat(two,axis=1)

# %%
preprocessed
# Out:
#        EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  DeptID  \
# 0    10026.0        0.0              0.0       1.0          1.0     5.0
# 1    10084.0        1.0              1.0       1.0          5.0     3.0
# 2    10196.0        1.0              1.0       0.0          5.0     5.0
# 3    10088.0        1.0              1.0       0.0          1.0     5.0
# 4    10069.0        0.0              2.0       0.0          5.0     5.0
# ..       ...        ...              ...       ...          ...     ...
# 306  10135.0        0.0              0.0       1.0          1.0     5.0
# 307  10301.0        0.0              0.0       0.0          5.0     5.0
# 308  10010.0        0.0              0.0       0.0          1.0     3.0
# 309  10043.0        0.0              0.0       0.0          1.0     3.0
# 310  10271.0        0.0              4.0       0.0          1.0     5.0
#
#      PerfScoreID  FromDiversityJobFairID    Salary  Termd  ...  RaceDesc  \
# ...

# %%
preprocessed.to_csv("PreHRDataset_v14data.csv",index=False)
